# %%
from img_process import img_all_convert, img_all_resize, img_all_to_grey
from img2data import load, file_split, extract, train_test_split_folder
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nw_folder_path = "./nws/"
not_nw_folder_path = "./notnw/"
train_folders_path = "./train/"
test_folders_path = "./test/"
train_size = 0.7
train_test_split_folder(nw_folder_path, not_nw_folder_path, train_folders_path, test_folders_path, train_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6922566ada62> in <module>()
#       4 test_folder_path = "./test/"
#       5 train_size = 0.7
# ----> 6 train_test_split_folder(nw_folder_path, not_nw_folder_path, train_folder_path, test_folder_path, train_size)
#
# /Users/nataliezhu/Documents/sem_computer_vision/NWs/img2data.py in train_test_split_folder(nw_folder_path, not_nw_folder_path, train_folders_path, test_folders_path, train_size)
#     135     imgs = (nw_train, nw_test, not_nw_train, not_nw_test)
#     136     folder_names = (nw_folder_path, nw_folder_path, not_nw_folder_path, not_nw_folder_path)
# --> 137     dest_names = (train_folder_path + "nws", test_folder_path + "nws",
#     138                   train_folder_path + "not_nws", test_folder_path + "not_nws")
#     139     print imgs
#
# NameError: global name 'train_folder_path' is not defined

# %% [markdown]
# change image size all to 1000 * 1000. change to greyscale.

# %%
image_height = 1000
image_width = 1000
max_num_images = 10000

# %%
#img_all_resize('./img/nws', './nws', (image_height, image_width))
#img_all_to_grey('./nws', './nws')

# %%
#img_all_resize('./img/notnw', './notnw', (image_height, image_width))
#img_all_to_grey('./notnw', './notnw')

# %%
data_folders = extract('./train/')
# Out:
# ['./train/notnw', './train/nws']

# %%
data, labels = load(data_folders, max_num_images, image_height, image_width)
# Out:
# Could not read: ./train/notnw/.DS_Store : cannot identify image file './train/notnw/.DS_Store' - it's ok, skipping.
# Full dataset tensor: (183, 1000, 1000)
# Mean: -0.204055
# Standard deviation: 0.156474
# Labels: (183,)

# %%
print data.shape
print labels.shape
# Out:
# (183, 1000, 1000)
# (183,)

# %%
plt.imshow(data[176], cmap = "gray")
plt.show()
